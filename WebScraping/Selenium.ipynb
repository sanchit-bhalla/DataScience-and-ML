# %%
path = 'C:/Users/mehak/Downloads/chromedriver'

# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path = path)
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="3953a9753456fc8f84952b57130bbe8a")>

# %%
driver.get('https://codingninjas.in')

# %%
driver.title
# Out:
# "Practice & Learn Coding Online at India's Best Coding Courses - Coding Ninjas"

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('test_shot.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en" style="--batchMonthBG:#FFEBC2; --batchCardBC:#FFEBC2; --batchMonthTC:#AC933C;"><head>\n    <meta charset="utf-8">\n    <title>Practice &amp; Learn Coding Online at India\'s Best Coding Courses - Coding Ninjas</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas">\n    <meta property="og:title" content="Practice &amp; Learn Coding Online at India\'s Best Coding Courses - Coding Ninjas">\n    <meta name="description" content="Practice Coding Online at Coding Ninjas which is India\'s best Programming and software training institute that offers courses in Java, C++, Android, Data Structure, Web Development, Ruby on Rails and more. Registration open for Online Coding Classes and offline Coding Classes in Delhi.">\n    <meta property="og:description" content="Practice Coding Online at Coding Ninjas which is India\'s best Programming and software training institute that off
# ...

# %%
event_btn = driver.find_element_by_link_text('Events')
event_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="45b7c69dcfe0ab90e72fffcb924d6b06", element="75e82612-5b9e-4e22-b82b-2823bd5cdf0b")>

# %%
event_btn.click()

# %%
home = driver.find_element_by_partial_link_text('Hom')
home.click()

# %%
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.get(driver.current_url) #same as refresh

# %% [markdown]
# ### Locate elements

# %%
driver.get('https://books.toscrape.com')

# %%
mstry = driver.find_element_by_link_text('Mystery')
mstry.click()

# %%
b1 = driver.find_element_by_partial_link_text('Poisonous')
b1.click()

# %%
driver.back()

# %%
i1 = driver.find_element_by_class_name('image_container')
i1.click()

# %%
driver.back()

# %%
li = driver.find_elements_by_class_name('image_container')
print(len(li))
# Out:
# 20

# %%
driver.find_element_by_tag_name('img')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="45b7c69dcfe0ab90e72fffcb924d6b06", element="fb4f6ccd-8888-4d86-a1fb-517e6930485c")>

# %%
a = driver.find_element_by_name('viewport')
type(a)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
c = driver.find_element_by_class_name('price_color')
c.click() # Nothing happens bcz c is not a clickable

# %%
# c.clear() #error

# %%
c.text
# Out:
# '£47.82'

# %%
c.tag_name
# Out:
# 'p'

# %%
c.get_attribute('class')
# Out:
# 'price_color'

# %%
c.get_attribute('href') # None

# %% [markdown]
# ### Click on advance algorithm
# https://codezen.codingninjas.com/dashboard?_ga=2.95642265.484345953.1592334090-438330456.1592334090

# %%
driver.get('https://codezen.codingninjas.com/dashboard?_ga=2.95642265.484345953.1592334090-438330456.1592334090')

# %%
li = driver.find_elements_by_class_name('category-card')
print(len(li))
li[2].click()
# Out:
# 5

# %% [markdown]
# ### Open Google and Perform the following Steps :
# ### 1.Click on a link that has string “mage” present in it.
# ### 2.Find the title of the new page.
# ### 3.Go back to the previous page.

# %%
driver.get('https://www.google.com/')

# %%
driver.find_element_by_link_text('Images').click()

# %%
print(driver.title)
# Out:
# Google Images

# %%
driver.back()

# %% [markdown]
# ### Find the element with address tag on the page
#     https://www.codingninjas.com/courses?_ga=2.100231835.484345953.1592334090-438330456.1592334090

# %%
driver.get('https://www.codingninjas.com/courses?_ga=2.100231835.484345953.1592334090-438330456.1592334090')

# %%
#driver.find_element_by_tag_name('address')

# %% [markdown]
# ### Locate text box with name=”firstname”. Check if it is enabled or not.
# ### NOTE: YOU NEED TO LOGOUT FROM YOUR FACEBOOK ACCOUNT TO ACCESS THE SIGN UP PAGE.
# https://www.facebook.com/r.php

# %%
driver.get('https://www.facebook.com/r.php')

# %%
fname = driver.find_element_by_tag_name('input')

# %%
fname.is_enabled()
# Out:
# True

# %% [markdown]
# ### What happens when we click on element with id = ‘day’?
# https://www.facebook.com/r.php

# %%
driver.get('https://www.facebook.com/r.php')

# %%
ele = driver.find_element_by_id('day')

# %%
ele.click()

# %% [markdown]
# ### Open Facebook Sign Up and Perform the following Steps :
# ### 1.Check if Radio button with female is selected or not.
# ### 2.Select it.
# ### 3.Check again if it now selected or not.

# %%
driver.get('https://www.facebook.com/r.php')

# %%
female = driver.find_element_by_id('u_0_6')

# %%
female.is_selected()
# Out:
# False

# %%
female.click()

# %%
female.is_selected()
# Out:
# True

# %% [markdown]
# ### Click on DS → Graph. Find and print name of all the problems which are listed under section “Topological Sorting”.
# https://www.geeksforgeeks.org/

# %%
driver.get('https://www.geeksforgeeks.org/')

# %%
t = driver.find_element_by_id('menu-item-351946')

# %%
t.click()

# %%
ds = driver.find_element_by_id('menu-item-351977')

# %%
ds.click() # click on DS

# %%
graphs = driver.find_element_by_id('menu-item-351989')
graphs.click() # click on graph section

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(driver.page_source, 'lxml')
ts_div = data.find(class_ = 'topologicalSorting')
li = ts_div.find_all('li')
for i in li:
    print(i.string)
# Out:
# Topological Sorting
# All topological sorts of a Directed Acyclic Graph
# Kahn’s Algorithm for Topological Sorting
# Maximum edges that can be added to DAG so that is remains DAG
# Longest path between any pair of vertices
# Longest Path in a Directed Acyclic Graph
# Longest Path in a Directed Acyclic Graph | Set 2
# Topological Sort of a graph using departure time of vertex
# Given a sorted dictionary of an alien language, find order of characters

# %%
driver.get('https://books.toscrape.com')

# %%
ans = driver.find_element_by_xpath('/html/head/title')

# %%
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/ul')
ans.get_attribute('outerHTML')
# Out:
# '<ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>'

# %%
ans = driver.find_element_by_xpath('//ul[@class="breadcrumb"]')
ans.get_attribute('outerHTML')
# Out:
# '<ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>'

# %%
ans = driver.find_elements_by_xpath('//ul')
len(ans)
# Out:
# 4

# %%
ans = driver.find_element_by_xpath('//*') # Full page source
ans.get_attribute('outerHTML')
# Out:
# '<html lang="en-us" class="no-js"><!--<![endif]--><head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n        <meta name="created" content="24th Jun 2016 09:29">\n        <meta name="description" content="">\n        <meta name="viewport" content="width=device-width">\n        <meta name="robots" content="NOARCHIVE,NOCACHE">\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="static/oscar/favicon.ico">\n        \n\n        \n        \n    \n    \n        <link rel="stylesheet" type="text/css" href="static/oscar/css/styles.css">\n    \n    <link rel="stylesheet" href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css">\n    <link rel="stylesheet" type="text/cs
# ...

# %%
ans = driver.find_element_by_xpath('//div[contains(@class,"h1")]')
ans.get_attribute('outerHTML')
# Out:
# '<div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>'

# %%
ans = driver.find_element_by_xpath('//div[starts-with(@class,"col")]')
ans.get_attribute('outerHTML')
# Out:
# '<div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>'

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li')
ans.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>'

# %% [markdown]
# ### Predicate

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[4]')
ans.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books/sequential-art_5/index.html">\n                            \n                                Sequential Art\n                            \n                        </a>\n\n                        </li>'

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[last()]')
ans.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books/crime_51/index.html">\n                            \n                                Crime\n                            \n                        </a>\n\n                        </li>'

# %%
ans = driver.find_elements_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[position()<3]')
len(ans)
# Out:
# 2

# %% [markdown]
# ### Using Css selector

# %%
ans = driver.find_element_by_css_selector('html head title')
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans = driver.find_element_by_css_selector('html>head>title')
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans = driver.find_element_by_css_selector('div.page_inner ul li')
ans.get_attribute('outerHTML')
# Out:
# '<li>\n            <a href="index.html">Home</a>\n        </li>'

# %%
ans = driver.find_element_by_css_selector('div.page_inner>ul>li')
ans.get_attribute('outerHTML')
# Out:
# '<li>\n            <a href="index.html">Home</a>\n        </li>'

# %% [markdown]
# ### Type into fields
# ### search Selenium in google

# %%
driver.get('https://www.google.com')

# %%
text_box = driver.find_element_by_name('q')

# %%
text_box.send_keys("Selenium")

# %%
text_box.submit()

# %% [markdown]
# ### Search coding ninzas using googlemaps

# %%
driver.get('https://www.google.com/maps')

# %%
text_box = driver.find_element_by_name('q')

# %%
text_box.send_keys('Coding Ninjas')

# %%
driver.find_element_by_id('searchbox-searchbutton').click()

# %%
driver.get('https://www.nga.gov/collection/artists.html')

# %%
a = driver.find_element_by_css_selector('dt.title a')
a.get_attribute('innerHTML')
# Out:
# '107 Workshop'

# %% [markdown]
# ### Open Gmail,Enter your login id and password and login to your account.

# %%
# Not working . bcz of security

# %% [markdown]
# ### Find all the plans of Airtel in Delhi NCR(Find Price)
# https://paytm.com/recharge

# %%
driver.get('https://paytm.com/recharge')

# %%
operator = driver.find_element_by_xpath('//div[@class="_1exI"]/input')

# %%
operator.send_keys('Airtel')

# %%
circle = driver.find_element_by_xpath('//div[@class="dfy8"]/ul/li[3]//input')
circle
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="074b79678626350f306a58302eb52600", element="4edbdb1c-80f0-41f7-919f-c23e6cf4f493")>

# %%
circle.send_keys('Delhi NCR')

# %%
prices = driver.find_elements_by_xpath('//div[@class = "zUDk _17KN"]/button')
for i in prices:
    print(i.get_attribute('innerHTML'))
# Out:
# Rs. 98
# Rs. 149
# Rs. 179
# Rs. 219
# Rs. 249
# Rs. 251
# Rs. 279
# Rs. 298
# Rs. 349
# Rs. 398
# Rs. 399
# Rs. 401
# Rs. 449
# Rs. 558
# Rs. 598
# Rs. 698

# %% [markdown]
# ### Search iphone in the search bar and give the prices of first 4 results
# https://paytm.com/

# %%
driver.get('https://paytm.com/')

# %%
text_box = driver.find_element_by_xpath('//div[@class="_3HxD"]/input')
text_box.send_keys("iphone")

# %%
text_box.send_keys(u'\ue007') # Press enter

# %%
price_list = driver.find_elements_by_class_name('_1kMS')
#print 1st 4 prices
for i in range(4):
    print(price_list[i].get_attribute('innerHTML'))
# Out:
# Rs 68300
# Rs 31500
# Rs 73600
# Rs 31500

# %% [markdown]
# ### Click on BST and find out the accuracy of the first 10 questions of BST
# https://practice.geeksforgeeks.org/

# %%
driver.get('https://practice.geeksforgeeks.org/')

# %%
driver.find_element_by_link_text('Practice').click()

# %%
driver.find_element_by_link_text('BST').click()

# %%
li = driver.find_elements_by_xpath('//div[@class="panel-body"]/div/div[3]')
for i in range(10):
    print(li[i].get_attribute('title'))
# Out:
# 62.66%
# 59.63%
# 58.44%
# 55.04%
# 54.24%
# 51.83%
# 50.5%
# 50.22%
# 50%
# 50%

# %%
driver.quit()

# %% [markdown]
# ### Find the problem title of 15th question of the first 2 data structures
# https://practice.geeksforgeeks.org/

# %%
from selenium import webdriver
path = 'C:/Users/mehak/Downloads/chromedriver'
driver = webdriver.Chrome(executable_path = path)
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="6c2682eab7960d277654a8e58e7e71d3")>

# %%
driver.get('https://practice.geeksforgeeks.org/')

# %%
driver.find_element_by_link_text('Practice').click()

# %%
driver.find_element_by_link_text('Array').click()

# %%
from bs4 import BeautifulSoup
data = BeautifulSoup(driver.page_source, 'lxml')
problems = data.find(id='problemFeed')
problem_list = problems.find_all(class_='panel-body')
req = problem_list[14] # 15 question
print(req.span.string)
# Out:
# Subarrays with equal 1s and 0s

# %%
# Now driver.back() and do same process with linkd list

# %% [markdown]
# ### Open Coding Ninjas instagram handle and print the Post Content(including comments) of the first 5 posts.
# https://www.instagram.com/coding.ninjas/

# %%
driver.get('https://www.instagram.com/coding.ninjas/')

# %%
# click on Login 
driver.find_element_by_link_text('Log In').click()

# %%
text_box = driver.find_element_by_name('username')
text_box.send_keys('python414')

password = 'PASSWORD' # use yor password
pass_box = driver.find_element_by_name('password')
pass_box.send_keys(password)

text_box.send_keys(u'\ue007') # Press enter

# %%
driver.find_element_by_xpath('//button[contains(@class,"HoLwm")]').click() # Don't save information for now

# %%
for i in range(5):
    driver.get('https://www.instagram.com/coding.ninjas/')
    post = driver.find_elements_by_xpath('//div[@class = "_9AhH0"]')[i] # ist 5 posts
    post.click()

# %%
driver.quit()
